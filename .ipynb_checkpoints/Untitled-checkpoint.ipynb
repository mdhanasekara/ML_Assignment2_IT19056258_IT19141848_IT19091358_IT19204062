# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 349B-CF8C
#
#  Directory of C:\Users\User\Desktop\ML_Assignment2_IT19056258_IT19141848_IT19091358_IT19204062
#
# 05/22/2022  01:30 PM    <DIR>          .
# 05/22/2022  01:30 PM    <DIR>          ..
# 05/22/2022  01:30 PM    <DIR>          .ipynb_checkpoints
# 05/22/2022  01:30 PM            29,644 Customertravel.csv
# 05/22/2022  01:30 PM           100,293 Untitled.ipynb
#                2 File(s)        129,937 bytes
#                3 Dir(s)  254,723,555,328 bytes free

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
customer_travel_churn_data = pd.read_csv('Customertravel.csv')

# %%
customer_travel_churn_data.head()
# Out:
#    Age FrequentFlyer AnnualIncomeClass  ServicesOpted  \
# 0   34            No     Middle Income              6
# 1   34           Yes        Low Income              5
# 2   37            No     Middle Income              3
# 3   30            No     Middle Income              2
# 4   30            No        Low Income              1
#
#   AccountSyncedToSocialMedia BookedHotelOrNot  Target
# 0                         No              Yes       0
# 1                        Yes               No       1
# 2                        Yes               No       0
# 3                         No               No       0
# 4                         No               No       0

# %%
customer_travel_churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         954 non-null    int64
#  1   FrequentFlyer               954 non-null    object
#  2   AnnualIncomeClass           954 non-null    object
#  3   ServicesOpted               954 non-null    int64
#  4   AccountSyncedToSocialMedia  954 non-null    object
#  5   BookedHotelOrNot            954 non-null    object
#  6   Target                      954 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 52.3+ KB

# %%
customer_travel_churn_data.isnull()
# Out:
#        Age  FrequentFlyer  AnnualIncomeClass  ServicesOpted  \
# 0    False          False              False          False
# 1    False          False              False          False
# 2    False          False              False          False
# 3    False          False              False          False
# 4    False          False              False          False
# ..     ...            ...                ...            ...
# 949  False          False              False          False
# 950  False          False              False          False
# 951  False          False              False          False
# 952  False          False              False          False
# 953  False          False              False          False
#
#      AccountSyncedToSocialMedia  BookedHotelOrNot  Target
# 0                         False             False   False
# 1                         False             False   False
# 2                         False             False   False
# ...

# %%
sns.heatmap(customer_travel_churn_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='Target',customer_travel_churn_data)
# Out:
#   File "C:\Users\User\AppData\Local\Temp/ipykernel_6384/1040878583.py", line 1
#     sns.countplot(x='Target',customer_travel_churn_data)
#                                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
sns.countplot(x='Target',data=customer_travel_churn_data)

# %%
sns.countplot(x='Target',hue='AnnualIncomeClass',data=customer_travel_churn_data)

# %%
customer_travel_churn_data

# %%
yes_no_mapping = {'Yes' : 1, 'No' :0, 'No Record':0}
customer_travel_churn_data['FrequentFlyer']=customer_travel_churn_data['FrequentFlyer'].map(yes_no_mapping)
customer_travel_churn_data['AccountSyncedToSocialMedia']=customer_travel_churn_data['AccountSyncedToSocialMedia'].map(yes_no_mapping)
customer_travel_churn_data['BookedHotelOrNot']=customer_travel_churn_data['BookedHotelOrNot'].map(yes_no_mapping)

# %%
customer_travel_churn_data

# %%
AnnualIncome_mapping = {'Middle Income' : 'M', 'Low Income' :'L', 'High Income':'H'}
customer_travel_churn_data['AnnualIncomeClass']=customer_travel_churn_data['AnnualIncomeClass'].map(AnnualIncome_mapping)

# %%
customer_travel_churn_data

# %%
pd.get_dummies(customer_travel_churn_data)['AnnualIncomeClass'],drop_first =True)

# %%
pd.get_dummies(customer_travel_churn_data['AnnualIncomeClass'],drop_first =True)

# %%
AnnualIncomeClass.head()

# %%
AnnualIncomeClass = pd.get_dummies(customer_travel_churn_data['AnnualIncomeClass'],drop_first =True)

# %%
AnnualIncomeClass
# Out:
#      Low Income  Middle Income
# 0             0              1
# 1             1              0
# 2             0              1
# 3             0              1
# 4             1              0
# ..          ...            ...
# 949           1              0
# 950           0              1
# 951           0              1
# 952           1              0
# 953           0              0
#
# [954 rows x 2 columns]

# %%
AnnualIncomeClass.head()
# Out:
#    Low Income  Middle Income
# 0           0              1
# 1           1              0
# 2           0              1
# 3           0              1
# 4           1              0

# %%
customer_travel_churn_data = pd.concat([customer_travel_churn_data,AnnualIncomeClass],axis=1)

# %%
customer_travel_churn_data
# Out:
#      Age FrequentFlyer AnnualIncomeClass  ServicesOpted  \
# 0     34            No     Middle Income              6
# 1     34           Yes        Low Income              5
# 2     37            No     Middle Income              3
# 3     30            No     Middle Income              2
# 4     30            No        Low Income              1
# ..   ...           ...               ...            ...
# 949   31           Yes        Low Income              1
# 950   30            No     Middle Income              5
# 951   37            No     Middle Income              4
# 952   30            No        Low Income              1
# 953   31           Yes       High Income              1
#
#     AccountSyncedToSocialMedia BookedHotelOrNot  Target  Low Income  \
# 0                           No              Yes       0           0
# 1                          Yes               No       1           1
# 2                          Yes               No       0           0
# ...

# %%
customer_travel_churn_data.drop(['AnnualIncomeClass'],axis =1,inplace=True)

# %%
customer_travel_churn_data
# Out:
#      Age FrequentFlyer  ServicesOpted AccountSyncedToSocialMedia  \
# 0     34            No              6                         No
# 1     34           Yes              5                        Yes
# 2     37            No              3                        Yes
# 3     30            No              2                         No
# 4     30            No              1                         No
# ..   ...           ...            ...                        ...
# 949   31           Yes              1                         No
# 950   30            No              5                         No
# 951   37            No              4                         No
# 952   30            No              1                        Yes
# 953   31           Yes              1                         No
#
#     BookedHotelOrNot  Target  Low Income  Middle Income
# 0                Yes       0           0              1
# 1                 No       1           1              0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lblEnc = LabelEncoder()
customer_churn_data_ccd = customer_travel_churn_data.copy()

for i in customer_travel_churn_data.columns:
    customer_churn_data_ccd[i] = lblEnc.fit_transform(customer_travel_churn_data[i])

# %%
customer_churn_data_ccd
# Out:
#      Age  FrequentFlyer  ServicesOpted  AccountSyncedToSocialMedia  \
# 0      6              0              5                           0
# 1      6              2              4                           1
# 2      9              0              2                           1
# 3      3              0              1                           0
# 4      3              0              0                           0
# ..   ...            ...            ...                         ...
# 949    4              2              0                           0
# 950    3              0              4                           0
# 951    9              0              3                           0
# 952    3              0              0                           1
# 953    4              2              0                           0
#
#      BookedHotelOrNot  Target  Low Income  Middle Income
# 0                   1       0           0              1
# ...

# %%
X = customer_churn_data_ccd.drop('Target', axis=1)
Y = customer_churn_data_ccd['Target']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 2)

# %%
print(X_train.shape, '====> Training Feature Shape')
print(X_test.shape, '====> Testing Feature Shape')
print(y_train.shape, '====> Training Labels Shape')
print(y_test.shape, '====> Testing Labels Shape')
# Out:
# (763, 7) ====> Training Feature Shape
# (191, 7) ====> Testing Feature Shape
# (763,) ====> Training Labels Shape
# (191,) ====> Testing Labels Shape
